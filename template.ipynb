# %% [markdown]
# <a href="https://colab.research.google.com/github/mondragonStudent/colab-notebooks/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hide drive notification
from google.colab import output
output.eval_js('''
    const hideDialog = () => {
        document.querySelectorAll("[class*='drive-disabled']").forEach(el => {
            el.style.display = "none";
        });

        document.querySelectorAll("mwc-dialog[open]").forEach(el => {
            el.removeAttribute("open");
        });
    };

    hideDialog();
    setTimeout(hideDialog, 1000);
    setTimeout(hideDialog, 2000);

    null;
''')
