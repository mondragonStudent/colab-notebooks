# %% [markdown]
# <a href="https://colab.research.google.com/github/mondragonStudent/colab-notebooks/blob/mdc2026/Test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test 2")
# Out:
# test 2

# %%
x = 3
y = 4
print(f"the sum of 3 AND 4 IS {3+4} ")
# Out:
# the sum of 3 AND 4 IS 7

# %%
x = input("please type a number")
print(f"you typed {x}")
# Out:
# please type a number2
# you typed 2
